# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_data=ImageDataGenerator(rescale=1./255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True,vertical_flip=True)

# %%
test_data=ImageDataGenerator(rescale=1./255)

# %%
train_data_generator=train_data.flow_from_directory(directory="/content/drive/MyDrive/Deep Learning/day 7 cnn /train (1)",target_size=(256,256))
# Out:
# Found 13 images belonging to 3 classes.

# %%
test_data_generator=test_data.flow_from_directory(directory="/content/drive/MyDrive/Deep Learning/day 7 cnn /test",target_size=(256,256))
# Out:
# Found 8 images belonging to 3 classes.

# %%
train_data_generator.class_indices
# Out:
# {'rock': 0, 'shah rukh khan': 1, 'tom': 2}

# %%
test_data_generator.class_indices
# Out:
# {'rock': 0, 'shah': 1, 'tom': 2}

# %%
train_data_generator.image_shape
# Out:
# (256, 256, 3)

# %%
from keras import Sequential
from keras.layers import Conv2D,MaxPooling2D,Flatten,Dense

# %%
model=Sequential()

model.add(Conv2D(input_shape=(256,256,3),filters=8,kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2),strides=2))

model.add(Conv2D(filters=8,kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2),strides=2))

model.add(Conv2D(filters=16,kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2),strides=2))

model.add(Flatten())

model.add(Dense(units=30,activation='relu'))

model.add(Dense(units=3,activation='softmax'))


model.summary()
# Out:
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_20 (Conv2D)              │ (None, 256, 256, 8)    │           224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_20 (MaxPooling2D) │ (None, 128, 128, 8)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_21 (Conv2D)              │ (None, 128, 128, 8)    │           584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_21 (MaxPooling2D) │ (None, 64, 64, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_22 (Conv2D)              │ (None, 64, 64, 16)     │         1,168 │
# ...

# %%
model.compile(optimizer='rmsprop', loss="categorical_crossentropy", metrics=["accuracy"])

# %%
model=model.fit(x=train_data_generator,epochs=10,validation_data=(test_data_generator))
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - accuracy: 0.1538 - loss: 1.1141 - val_accuracy: 0.3750 - val_loss: 1.2389
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - accuracy: 0.5385 - loss: 1.0091 - val_accuracy: 0.2500 - val_loss: 1.5154
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.3846 - loss: 1.3697 - val_accuracy: 0.3750 - val_loss: 1.3658
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.3846 - loss: 1.2381 - val_accuracy: 0.3750 - val_loss: 1.1187
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.5385 - loss: 1.0477 - val_accuracy: 0.2500 - val_loss: 1.1302
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.4615 - loss: 1.0308 - val_accuracy: 0.3750 - val_loss: 1.1325
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.3846 - loss: 1.0220 - val_accuracy: 0.3750 - val_loss: 1.1543
# Epoch 8/10
# ...
